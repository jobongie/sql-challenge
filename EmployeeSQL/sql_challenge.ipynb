# %% [markdown]
# # SQL Homework

# %% [markdown]
# ### Import Necessary Modules

# %%
# Basics
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlalchemy

# SQL specific
from sqlalchemy import create_engine, inspect
from sqlalchemy import create_engine, Column, Integer, String, Float

# %% [markdown]
# ###  Mapping, Engine Creation, Queries

# %%
## Currently have some issues I have not solved relating to 
## shells or drives or something. Quien Sabe

# Create Engine and Pass in Postgres Connection
# Setup to Connect to Database 
engine = create_engine('postgres://postgres:password1234@localhost:5432/sql_challenge')
conn = engine.connect()

# %% [markdown]
# ### Have issues, no technical mettle... importing as csv

# %%
# Import Salaries csv
file_path = os.path.join("..","data","salaries.csv")
salaries_df = pd.read_csv(file_path)
file_path = os.path.join("..","data","titles.csv")
titles_df = pd.read_csv(file_path)

salaries_df.head()
titles_df.head()

#merge_df = pd.merge(salaries_df,titles_df,how = 'left', on )
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
# %matplotlib notebook

# %%
# Create histogram
salaries = salaries_df["emp_no"]

#Visualization of salaries
plt.hist(salaries, density=True, color='green', alpha=0.6, label="Salaries")
plt.axvline(salaries.mean(), color='darkred', linestyle='dashed', linewidth=1)
plt.ylabel("Frequency")
plt.xlabel("Salaries")
plt.title("Frequency of 80's to 90's Salaries from defunct company")
plt.legend()

file_name = ("Frequency of 80's to 90's Salaries from defunct company.png") 
output_path = os.path.join(".", "Images", file_name)
plt.savefig(output_path)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Bar chart
plt.bar(x=x_axis,height=tx_tot,color='blue', width=width, label="Salary", alpha=.5,align="center")
